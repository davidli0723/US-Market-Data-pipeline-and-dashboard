# %%
# %sql
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.stocks_price_history_raw;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.indexes_price_history;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.stocks_info;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.balance_sheet;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.income_statement;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.cash_flow;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.stocks_price_history_with_ma;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.stocks_daily_return;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.stocks_monthly_return;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.stocks_annual_return;
DROP TABLE IF EXISTS yfinance_pipeline_prod.stocks_dataset.stocks_below_ma_counts;

# %%
# %sql
SELECT * FROM yfinance_pipeline_dev.stocks_dataset.stocks_price_history_raw
WHERE date = (SELECT MAX(date) FROM yfinance_pipeline_dev.stocks_dataset.stocks_price_history_raw);

# %%
# %sql
DELETE FROM yfinance_pipeline_dev.stocks_dataset.stocks_price_history_raw
WHERE date = (SELECT MAX(date) FROM yfinance_pipeline_dev.stocks_dataset.stocks_price_history_raw);

# %%
# %sql
DELETE FROM yfinance_pipeline_dev.stocks_dataset.indexes_price_history
WHERE date = (SELECT MAX(date) FROM yfinance_pipeline_dev.stocks_dataset.indexes_price_history);

# %%
# %sql
DROP TABLE IF EXISTS yfinance_pipeline_dev.stocks_dataset.stocks_price_history_with_ma;

# %%
# %sql
SELECT * FROM yfinance_pipeline_dev.stocks_dataset.stocks_price_history_with_ma;
